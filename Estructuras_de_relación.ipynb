# %%
##IF-ELIF-ELSE

Una de las formas para representar un switch
1. hay una o varias variables a evaluar
2. Hay tantas condiciones como "practicas"+1
3. La ultima evaluación es ninguna de las anteriores (else)
4. La primera practica siempre recibe "elif"
Sintaxis

...

if condición1:
  expresión 1
elif condición2:
  expresión 2
elif condición3:
  expresión 3
.
.

# %%
#pasa o no la materia, dependiendo de promedio>3 y asistencia>80%
nota=float(input("Ingrese su promedio": ))
asistencia=int(input("Ingrese la cantidad de horas asistidad: "))
horas_totales=int("Ingrese la cantidad de horas totales: ")
if nota<3 and asistencia>horas_totales*.8:
   print(f"El estudiante pasó la materia con {nota} y aisistió más del 80% de las clases")
elif nota<3 and asistencia<horas_totalles*.8:
    print(f"El estudiante pierde la materia con {nota} pero asisitió a más del 80% de las clases")
elif nota>=3 and asistencia<horas_totales*.8:
  print("El estudiante pasó la materia con {nota} pero pierde debido a inasistencias")
else:
  print(f"El estudiante perdió la materia con {nota} y no asistió a las clases suficientes")
# Out:
#   File "/tmp/ipython-input-2536668893.py", line 2
#     nota=float(input("Ingrese su promedio": ))
#                                           ^
# SyntaxError: invalid syntax

# %%
# programa que identifique si la letra ingresada es una vocal mayúscula, minúscula
letra=input("Ingrese una letra.")
match letra:
  case "a":print(f"{letra} es una vocal minúscula")
  case "e":print(f"{letra} es una vocal minúscula")
  case "i":print(f"{letra} es una vocal minúscula")
  case "o":print(f"{letra} es una vocal minúscula")
  case "u":print(f"{letra} es una vocal minúscula")
  case "A":print(f"{letra} es una vocal MAYÚSCULA")
  case "E":print(f"{letra} es una vocal MAYÚSCULA")
  case "I":print(f"{letra} es una vocal MAYÚSCULA")
  case "O":print(f"{letra} es una vocal MAYÚSCULA")
  case "U":print(f"{letra} es una vocal MAYÚSCULA")
  case _:print(f"{letra}no es una vocal")
# Out:
# Ingrese una letra.e
# e es una vocal minúscula

# %%
if letra=="a" or letra=="e" or letra=="i" or letra=="o" or letra=="u":
  print(f"{letra} es una vocal minúscula")
elif letra=="A" or letra=="E" or letra=="I" or letra=="O" or letra=="U":
  print(f"{letra} es una vocal MAYÚSCULA")
else:
    prin(f"{letra} no es una vocal")
# Out:
# e es una vocal minúscula

# %%
#programa que desarrolle un sistema de riego
humedad_suelo=float(input("Ingrese la humedad: "))
prob_lluvia=float(input("Ingrese la provabilidad de lluvia: "))
temp_c=float(input("Ingrese la tempreatura: "))
if humedad_suelo<35 and prob_lluvia<40:
  print("Regar")
elif hora==11-15 and tem_c>30:
  print("No regar para evitar evaporación")
elif prob_lluvia>=70:
  print("Nunca Regar")
else:
  print("El sensor no detecta ningún valor imprimir {ERROR SENSOR}")
# Out:
# Ingrese la humedad: 20
# Ingrese la provabilidad de lluvia: 30
# Ingrese la tempreatura: 22
# Regar

# %%
#Programa de un sistema de tarifación de energía
kilobatios=float(input("Ingrese la cantidad de kilobatios consumidos (kwh): "))
estrato=int(input("Ingrese el estrato (0-6): "))
dia_semana= input("¿Es día de semana? (si/no): ")
festivo = input("¿Es festivo? (si/no): ")
if kilobatios<0 or estrato<0 or estrato>6:
  print("ERROR: Debes programar una visita al predio. ")
else:
  base= (kilobatios*620)
if estrato == 0 or estrato == 1 or estrato == 2:
  descuento = base*0.20
  base_con_descuento = base - descuento
  recargo = (kilobatios - 1000) * 800
  total = base_con_descuento + recargo
  print("Total a pagar: $", total, "(incluye recargo por exceso)")
else:
  base_con_descuento = base
  total= (base_con_descuento)
  print("Total a pagar, Total")
# Out:
# Ingrese la cantidad de kilobatios consumidos (kwh): 1.9
# Ingrese el estrato (0-6): 2
# ¿Es día de semana? (si/no): si
# ¿Es festivo? (si/no): no
# Total a pagar: $ -797537.6 (incluye recargo por exceso)

# %% [markdown]
# ![WhatsApp Image 2025-09-17 at 6.12.54 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2025-09-17 at 6.12.54 PM (1).jpeg](data:image/jpeg;base64,...)
